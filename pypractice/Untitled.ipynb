# %%
import requests

# %%
from requests.auth import HTTPBasicAuth
user = ''
key = r'qFYeaKyuGFS3ln01iIKPEZqFF31GciteGOzqzri4'

query = r'''https://api.open.fec.gov/v1/candidates/search/?year=2021&sort=name&per_page=20&api_key={}'''.format(key)

req = requests.get(query,verify = False)

print(req.text)
# Out:
# C:\Users\E0715367\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.open.fec.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...
